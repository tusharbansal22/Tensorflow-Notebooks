# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharbansal22/Tensorflow-Notebooks/blob/main/matplotlib/Matplotlib_Tut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,20,1000)

# %%
y=np.sin(x)+x*0.2

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('my plot');

# %% [markdown]
# ## Scatterplot

# %%
X=np.random.randn(100,2)
plt.scatter(X[:,0],X[:,1])

# %%
X=np.random.randn(200,2)
X[:50]+=3
Y=np.zeros(200)
Y[:50]=1
plt.scatter(X[:,0],X[:,1],c=Y);

# %% [markdown]
# ## Histogram

# %%
X= np.random.randn(10000)
plt.hist(X)
# Out:
# (array([  11.,   89.,  488., 1557., 2624., 2755., 1727.,  599.,  135.,
#           15.]),
#  array([-3.80001078, -3.05011775, -2.30022471, -1.55033167, -0.80043864,
#         -0.0505456 ,  0.69934744,  1.44924048,  2.19913351,  2.94902655,
#          3.69891959]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(X,bins=50)
# Out:
# (array([  2.,   1.,   2.,   0.,   6.,   7.,   9.,  17.,  22.,  34.,  50.,
#          57.,  95., 126., 160., 203., 280., 326., 336., 412., 455., 483.,
#         577., 565., 544., 591., 595., 555., 490., 524., 456., 393., 379.,
#         258., 241., 176., 162., 106.,  84.,  71.,  46.,  31.,  23.,  29.,
#           6.,   5.,   5.,   1.,   0.,   4.]),
#  array([-3.80001078, -3.65003218, -3.50005357, -3.35007496, -3.20009635,
#         -3.05011775, -2.90013914, -2.75016053, -2.60018192, -2.45020332,
#         -2.30022471, -2.1502461 , -2.00026749, -1.85028889, -1.70031028,
#         -1.55033167, -1.40035306, -1.25037446, -1.10039585, -0.95041724,
#         -0.80043864, -0.65046003, -0.50048142, -0.35050281, -0.20052421,
#         -0.0505456 ,  0.09943301,  0.24941162,  0.39939022,  0.54936883,
#          0.69934744,  0.84932605,  0.99930465,  1.14928326,  1.29926187,
#          1.44924048,  1.59921908,  1.74919769,  1.8991763 ,  2.04915491,
# ...

# %%
X=np.random.random(10000)
plt.hist(X,bins=50);

# %% [markdown]
# ## Plotting

# %%
# !wget https://github.com/tusharbansal22/polaris/blob/main/img/mentors/c2.jpg?raw=true
# Out:
# --2023-01-21 02:25:50--  https://github.com/tusharbansal22/polaris/blob/main/img/mentors/c2.jpg?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/tusharbansal22/polaris/raw/main/img/mentors/c2.jpg [following]
# --2023-01-21 02:25:50--  https://github.com/tusharbansal22/polaris/raw/main/img/mentors/c2.jpg
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/tusharbansal22/polaris/main/img/mentors/c2.jpg [following]
# --2023-01-21 02:25:51--  https://raw.githubusercontent.com/tusharbansal22/polaris/main/img/mentors/c2.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
from PIL import Image
im= Image.open('c2.jpg?raw=true')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr = np.array(im)

# %%
arr
# Out:
# array([[[ 42,  52,  51],
#         [ 63,  69,  69],
#         [ 99, 101, 100],
#         ...,
#         [ 84,  97, 106],
#         [ 85,  98, 106],
#         [ 89,  99, 109]],
#
#        [[ 50,  59,  56],
#         [ 69,  75,  75],
#         [108, 109, 111],
#         ...,
#         [ 80,  93, 102],
#         [ 86,  96, 105],
#         [ 87,  97, 107]],
#
#        [[ 59,  65,  63],
#         [ 86,  90,  89],
#         [116, 118, 117],
#         ...,
#         [ 85,  95, 104],
#         [ 92, 101, 110],
#         [ 95, 104, 113]],
#
#        ...,
#
#        [[165, 156, 151],
#         [166, 155, 151],
#         [164, 153, 149],
#         ...,
#         [149, 148, 146],
#         [148, 147, 145],
#         [147, 146, 144]],
#
#        [[164, 153, 147],
#         [169, 158, 154],
#         [169, 158, 154],
#         ...,
#         [148, 147, 145],
#         [147, 146, 144],
#         [148, 147, 145]],
#
#        [[165, 154, 150],
#         [161, 150, 146],
#         [164, 153, 149],
# ...

# %%
arr.shape
# Out:
# (811, 811, 3)

# %%
plt.imshow(arr);

# %%
plt.imshow(im);

# %%
gray=arr.mean(axis=2)
gray.shape
# Out:
# (811, 811)

# %%
plt.imshow(gray)

# %%
plt.imshow(gray,cmap='gray')
